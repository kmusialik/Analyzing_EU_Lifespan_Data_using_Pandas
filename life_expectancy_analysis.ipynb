# %%
import pandas as pd

# %%
df = pd.read_csv('demo_r_mlifexp.tsv', delimiter='\t')

# %%
df.head()
# Out:
#   unit,sex,age,geo\time  2021   2020   2019   2018   2017   2016    2015   \
# 0            YR,F,Y1,AL  77.2   79.4   80.4   80.2   79.7   79.8   79.2 e
# 1           YR,F,Y1,AL0     :   79.4   80.4   80.2   79.7   79.8   79.2 e
# 2          YR,F,Y1,AL01     :   79.2   80.1      :      :      :       :
# 3          YR,F,Y1,AL02     :   81.3   83.2      :      :      :       :
# 4          YR,F,Y1,AL03     :   77.9   78.4      :      :      :       :
#
#     2014  2013   ... 1999  1998  1997  1996  1995  1994  1993  1992  1991   \
# 0  79.9 e   : e  ...    :     :     :     :     :     :     :     :     :
# 1  79.9 e    :   ...    :     :     :     :     :     :     :     :     :
# 2      :     :   ...    :     :     :     :     :     :     :     :     :
# 3      :     :   ...    :     :     :     :     :     :     :     :     :
# 4      :     :   ...    :     :     :     :     :     :     :     :     :
#
#   1990
# 0    :
# 1    :
# 2    :
# 3    :
# 4    :
#
# [5 rows x 33 columns]

# %%
df.shape
# Out:
# (129000, 33)

# %%
params = df['unit,sex,age,geo\\time'].apply(pd.Series)

# %%
params.head()
# Out:
#               0
# 0    YR,F,Y1,AL
# 1   YR,F,Y1,AL0
# 2  YR,F,Y1,AL01
# 3  YR,F,Y1,AL02
# 4  YR,F,Y1,AL03

# %%
type(params)
# Out:
# pandas.core.frame.DataFrame

# %%
params.columns = ['a']

# %%
params.head()
# Out:
#               a
# 0    YR,F,Y1,AL
# 1   YR,F,Y1,AL0
# 2  YR,F,Y1,AL01
# 3  YR,F,Y1,AL02
# 4  YR,F,Y1,AL03

# %%
params = params.a.str.split(',', expand=True)

# %%
params.head()
# Out:
#     0  1   2     3
# 0  YR  F  Y1    AL
# 1  YR  F  Y1   AL0
# 2  YR  F  Y1  AL01
# 3  YR  F  Y1  AL02
# 4  YR  F  Y1  AL03

# %%
params.columns = ['unit', 'sex', 'age' ,'geo']

# %%
params.head()
# Out:
#   unit sex age   geo
# 0   YR   F  Y1    AL
# 1   YR   F  Y1   AL0
# 2   YR   F  Y1  AL01
# 3   YR   F  Y1  AL02
# 4   YR   F  Y1  AL03

# %%
merged = pd.concat([params, df], axis=1)

# %%
merged.head()
# Out:
#   unit sex age   geo unit,sex,age,geo\time  2021   2020   2019   2018   2017   \
# 0   YR   F  Y1    AL            YR,F,Y1,AL  77.2   79.4   80.4   80.2   79.7
# 1   YR   F  Y1   AL0           YR,F,Y1,AL0     :   79.4   80.4   80.2   79.7
# 2   YR   F  Y1  AL01          YR,F,Y1,AL01     :   79.2   80.1      :      :
# 3   YR   F  Y1  AL02          YR,F,Y1,AL02     :   81.3   83.2      :      :
# 4   YR   F  Y1  AL03          YR,F,Y1,AL03     :   77.9   78.4      :      :
#
#    ... 1999  1998  1997  1996  1995  1994  1993  1992  1991  1990
# 0  ...    :     :     :     :     :     :     :     :     :     :
# 1  ...    :     :     :     :     :     :     :     :     :     :
# 2  ...    :     :     :     :     :     :     :     :     :     :
# 3  ...    :     :     :     :     :     :     :     :     :     :
# 4  ...    :     :     :     :     :     :     :     :     :     :
#
# [5 rows x 37 columns]

# %%
merged.columns
# Out:
# Index(['unit', 'sex', 'age', 'geo', 'unit,sex,age,geo\time', '2021 ', '2020 ',
#        '2019 ', '2018 ', '2017 ', '2016 ', '2015 ', '2014 ', '2013 ', '2012 ',
#        '2011 ', '2010 ', '2009 ', '2008 ', '2007 ', '2006 ', '2005 ', '2004 ',
#        '2003 ', '2002 ', '2001 ', '2000 ', '1999 ', '1998 ', '1997 ', '1996 ',
#        '1995 ', '1994 ', '1993 ', '1992 ', '1991 ', '1990 '],
#       dtype='object')

# %%
merged = merged[['unit', 'sex', 'age', 'geo', '2020 ']]

# %%
merged.head()
# Out:
#   unit sex age   geo  2020
# 0   YR   F  Y1    AL  79.4
# 1   YR   F  Y1   AL0  79.4
# 2   YR   F  Y1  AL01  79.2
# 3   YR   F  Y1  AL02  81.3
# 4   YR   F  Y1  AL03  77.9

# %%
merged.age.unique().tolist()
# Out:
# ['Y1',
#  'Y10',
#  'Y11',
#  'Y12',
#  'Y13',
#  'Y14',
#  'Y15',
#  'Y16',
#  'Y17',
#  'Y18',
#  'Y19',
#  'Y2',
#  'Y20',
#  'Y21',
#  'Y22',
#  'Y23',
#  'Y24',
#  'Y25',
#  'Y26',
#  'Y27',
#  'Y28',
#  'Y29',
#  'Y3',
#  'Y30',
#  'Y31',
#  'Y32',
#  'Y33',
#  'Y34',
#  'Y35',
#  'Y36',
#  'Y37',
#  'Y38',
#  'Y39',
#  'Y4',
#  'Y40',
#  'Y41',
#  'Y42',
#  'Y43',
#  'Y44',
#  'Y45',
#  'Y46',
#  'Y47',
#  'Y48',
#  'Y49',
#  'Y5',
#  'Y50',
#  'Y51',
#  'Y52',
#  'Y53',
#  'Y54',
#  'Y55',
#  'Y56',
#  'Y57',
#  'Y58',
#  'Y59',
#  'Y6',
#  'Y60',
#  'Y61',
#  'Y62',
#  'Y63',
#  'Y64',
#  'Y65',
#  'Y66',
#  'Y67',
#  'Y68',
#  'Y69',
#  'Y7',
#  'Y70',
#  'Y71',
#  'Y72',
#  'Y73',
#  'Y74',
#  'Y75',
#  'Y76',
#  'Y77',
#  'Y78',
#  'Y79',
#  'Y8',
#  'Y80',
#  'Y81',
#  'Y82',
#  'Y83',
#  'Y84',
#  'Y9',
#  'Y_GE85',
#  'Y_LT1']

# %%
merged.shape
# Out:
# (129000, 5)

# %%
merged_noworodki = merged[merged.age == 'Y_LT1']

# %%
merged_noworodki.shape
# Out:
# (1500, 5)

# %%
merged_noworodki.head()
# Out:
#       unit sex    age   geo  2020
# 42500   YR   F  Y_LT1    AL  79.6
# 42501   YR   F  Y_LT1   AL0  79.6
# 42502   YR   F  Y_LT1  AL01  79.5
# 42503   YR   F  Y_LT1  AL02  81.5
# 42504   YR   F  Y_LT1  AL03  78.2

# %%
merged_noworodki.sex.unique().tolist()
# Out:
# ['F', 'M', 'T']

# %%
merged_noworodki_total = merged_noworodki[merged_noworodki.sex == 'T']

# %%
merged_noworodki_total.shape
# Out:
# (500, 5)

# %%
merged_noworodki_total.head()
# Out:
#        unit sex    age   geo  2020
# 128500   YR   T  Y_LT1    AL  77.4
# 128501   YR   T  Y_LT1   AL0  77.4
# 128502   YR   T  Y_LT1  AL01  77.3
# 128503   YR   T  Y_LT1  AL02  78.9
# 128504   YR   T  Y_LT1  AL03  76.2

# %%
merged_noworodki_total.unit.unique().tolist()
# Out:
# ['YR']

# %%
nuts = pd.read_csv('nuts.csv', on_bad_lines='skip', delimiter=';')

# %%
nuts.head()
# Out:
#   Code 2021          Country  \
# 0        BE  Belgique/België
# 1       BE1              NaN
# 2      BE10              NaN
# 3     BE100              NaN
# 4       BE2              NaN
#
#                                         NUTS level 1  \
# 0                                                NaN
# 1  Région de Bruxelles-Capitale/Brussels Hoofdste...
# 2                                                NaN
# 3                                                NaN
# 4                                      Vlaams Gewest
#
#                                         NUTS level 2  \
# 0                                                NaN
# 1                                                NaN
# 2  Région de Bruxelles-Capitale/ Brussels Hoofdst...
# 3                                                NaN
# 4                                                NaN
#
#                                         NUTS level 3  NUTS level  \
# 0                                                NaN         0.0
# ...

# %%
all_together = pd.merge(merged_noworodki_total, nuts, left_on='geo', right_on='Code 2021')

# %%
all_together.head()
# Out:
#   unit sex    age   geo  2020  Code 2021    Country NUTS level 1 NUTS level 2  \
# 0   YR   T  Y_LT1    AL  77.4         AL  Shqipëria          NaN          NaN
# 1   YR   T  Y_LT1   AL0  77.4        AL0        NaN    Shqipëria          NaN
# 2   YR   T  Y_LT1  AL01  77.3       AL01        NaN          NaN         Veri
# 3   YR   T  Y_LT1  AL02  78.9       AL02        NaN          NaN       Qender
# 4   YR   T  Y_LT1  AL03  76.2       AL03        NaN          NaN          Jug
#
#   NUTS level 3  ...                                         Unnamed: 9  \
# 0          NaN  ...                                                NaN
# 1          NaN  ...  The versions in Latin characters is not offici...
# 2          NaN  ...                                                NaN
# 3          NaN  ...                                                NaN
# 4          NaN  ...                                                NaN
#
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
all_together.head()
# Out:
#   unit sex    age   geo  2020  Code 2021    Country NUTS level 1 NUTS level 2  \
# 0   YR   T  Y_LT1    AL  77.4         AL  Shqipëria          NaN          NaN
# 1   YR   T  Y_LT1   AL0  77.4        AL0        NaN    Shqipëria          NaN
# 2   YR   T  Y_LT1  AL01  77.3       AL01        NaN          NaN         Veri
# 3   YR   T  Y_LT1  AL02  78.9       AL02        NaN          NaN       Qender
# 4   YR   T  Y_LT1  AL03  76.2       AL03        NaN          NaN          Jug
#
#   NUTS level 3  NUTS level  Country order  Region order  Unnamed: 8  \
# 0          NaN         0.0           35.0        1944.0         NaN
# 1          NaN         1.0           35.0        1945.0         NaN
# 2          NaN         2.0           35.0        1946.0         NaN
# 3          NaN         2.0           35.0        1952.0         NaN
# 4          NaN         2.0           35.0        1955.0         NaN
#
#                                           Unnamed: 9 Unnamed: 10 Unnamed: 11  \
# ...

# %%
all_together = all_together.iloc[:, 0:10]

# %%
all_together.head()
# Out:
#   unit sex    age   geo  2020  Code 2021    Country NUTS level 1 NUTS level 2  \
# 0   YR   T  Y_LT1    AL  77.4         AL  Shqipëria          NaN          NaN
# 1   YR   T  Y_LT1   AL0  77.4        AL0        NaN    Shqipëria          NaN
# 2   YR   T  Y_LT1  AL01  77.3       AL01        NaN          NaN         Veri
# 3   YR   T  Y_LT1  AL02  78.9       AL02        NaN          NaN       Qender
# 4   YR   T  Y_LT1  AL03  76.2       AL03        NaN          NaN          Jug
#
#   NUTS level 3
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
kraje = all_together[all_together.geo.str.len() == 2]

# %%
kraje.head()
# Out:
#    unit sex    age geo  2020  Code 2021                  Country NUTS level 1  \
# 0    YR   T  Y_LT1  AL  77.4         AL                Shqipëria          NaN
# 5    YR   T  Y_LT1  AT  81.3         AT               Österreich          NaN
# 18   YR   T  Y_LT1  BE  80.8         BE          Belgique/België          NaN
# 33   YR   T  Y_LT1  BG  73.6         BG                България           NaN
# 42   YR   T  Y_LT1  CH  83.1         CH  Schweiz/Suisse/Svizzera          NaN
#
#    NUTS level 2 NUTS level 3
# 0           NaN          NaN
# 5           NaN          NaN
# 18          NaN          NaN
# 33          NaN          NaN
# 42          NaN          NaN

# %%
kraje.shape
# Out:
# (37, 10)

# %%
kraje.sort_values(by='2020 ', ascending=True)
# Out:
#     unit sex    age geo    2020  Code 2021                  Country  \
# 33    YR   T  Y_LT1  BG    73.6         BG                България
# 360   YR   T  Y_LT1  RO   74.2 e        RO                  România
# 293   YR   T  Y_LT1  MK    74.4         MK       Северна Македонија
# 373   YR   T  Y_LT1  RS    74.5         RS            Srbija/Сpбија
# 280   YR   T  Y_LT1  LT    75.1         LT                  Lietuva
# 287   YR   T  Y_LT1  LV    75.5         LV                  Latvija
# 230   YR   T  Y_LT1  HU    75.7         HU             Magyarország
# 290   YR   T  Y_LT1  ME    75.9         ME               Црна Гора
# 324   YR   T  Y_LT1  PL  76.5 ep        PL                   Polska
# 396   YR   T  Y_LT1  SK    77.0         SK                Slovensko
# 0     YR   T  Y_LT1  AL    77.4         AL                Shqipëria
# 224   YR   T  Y_LT1  HR    77.8         HR                 Hrvatska
# 54    YR   T  Y_LT1  CZ    78.3         CZ                    Česko
# ...

# %%
nuts_1 = all_together[all_together.geo.str.len() == 3]

# %%
pd.set_option('display.max_rows', None)

# %%
nuts_1.sort_values(by='2020 ', ascending=True)
# Out:
#     unit sex    age  geo   2020  Code 2021 Country  \
# 34    YR   T  Y_LT1  BG3   72.9        BG3     NaN
# 364   YR   T  Y_LT1  RO2  73.5 e       RO2     NaN
# 377   YR   T  Y_LT1  RS2   74.2        RS2     NaN
# 361   YR   T  Y_LT1  RO1  74.2 e       RO1     NaN
# 39    YR   T  Y_LT1  BG4   74.3        BG4     NaN
# 294   YR   T  Y_LT1  MK0   74.4        MK0     NaN
# 367   YR   T  Y_LT1  RO3  74.5 e       RO3     NaN
# 370   YR   T  Y_LT1  RO4  74.6 e       RO4     NaN
# 238   YR   T  Y_LT1  HU3   74.7        HU3     NaN
# 374   YR   T  Y_LT1  RS1   74.7        RS1     NaN
# 281   YR   T  Y_LT1  LT0   75.1        LT0     NaN
# 288   YR   T  Y_LT1  LV0   75.5        LV0     NaN
# 339   YR   T  Y_LT1  PL7   75.6        PL7     NaN
# 234   YR   T  Y_LT1  HU2   75.7        HU2     NaN
# 291   YR   T  Y_LT1  ME0   75.9        ME0     NaN
# 332   YR   T  Y_LT1  PL5   76.3        PL5     NaN
# 328   YR   T  Y_LT1  PL4   76.4        PL4     NaN
# ...
